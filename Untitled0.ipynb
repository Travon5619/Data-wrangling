# %% [markdown]
# <a href="https://colab.research.google.com/github/Travon5619/Data-wrangling/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print("import package libraries")
# Out:
# import package libraries

# %%
tree_census = pd.read_csv('trees.csv')
print("load dataset may take long to load")
# Out:
# load dataset may take long to load

# %%
tree_census.head()
# Out:
#    created_at  tree_id block_id  \
# 0  08/27/2015  180,683  348,711
# 1  09/03/2015  200,540  315,986
# 2  09/05/2015  204,026  218,365
# 3  09/05/2015  204,337  217,969
# 4  08/30/2015  189,565  223,043
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
# 4   POINT (-73.97597938483258 40.66677775537875)        21           0
#
#   curb_loc status health                           spc_latin  ... st_assem  \
# 0   OnCurb  Alive   Fair                         Acer rubrum  ...       28
# 1   OnCurb  Alive   Fair                   Quercus palustris  ...       27
# 2   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...       50
# 3   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...       53
# 4   OnCurb  Alive   Good                     Tilia americana  ...       44
#
#   st_senate   nta            nta_name    boro_ct     state   Latitude  \
# 0        16  QN17        Forest Hills  4073900.0  New York  40.723092
# 1        11  QN49          Whitestone  4097300.0  New York  40.794111
# 2        18  BK90   East Williamsburg  3044900.0  New York  40.717581
# 3        18  BK90   East Williamsburg  3044900.0  New York  40.713537
# 4        21  BK37  Park Slope-Gowanus  3016500.0  New York  40.666778
#
#    longitude             x_sp            y_sp
# 0 -73.844215  1,027,431.14821  202,756.768749
# 1 -73.818679  1,034,455.70109  228,644.837379
# 2 -73.936608  1,001,822.83131  200,716.891267
# 3 -73.934456  1,002,420.35833  199,244.253136
# 4 -73.975979   990,913.775046  182,202.425999
#
# [5 rows x 42 columns]

# %%
tree_census.tail()
# Out:
#        created_at  tree_id block_id  \
# 14780  07/25/2015   93,564  349,179
# 14781  07/27/2015   97,139  513,595
# 14782  08/02/2015  111,730  109,625
# 14783  09/02/2015  199,021  107,590
# 14784  09/01/2015  195,981  104,434
#
#                                            the_geom  tree_dbh  stump_diam  \
# 14780  POINT (-73.86602234955035 40.73049700065828)         6           0
# 14781    POINT (-73.84223891180142 40.873194930179)         1           0
# 14782    POINT (-73.93797380200843 40.824545452066)        20           0
# 14783  POINT (-73.95793877060734 40.77193948245534)        13           0
# 14784   POINT (-73.9849596914058 40.74515035642465)         6           0
#
#       curb_loc status health                spc_latin  ... st_assem st_senate  \
# 14780   OnCurb  Alive   Good       Quercus imbricaria  ...       28        16
# 14781   OnCurb  Alive   Good            Acer palmatum  ...       83        36
# 14782   OnCurb  Alive   Good       Quercus imbricaria  ...       71        30
# 14783   OnCurb  Alive   Good  Styphnolobium japonicum  ...       76        28
# 14784   OnCurb  Alive   Good  Styphnolobium japonicum  ...       75        28
#
#         nta                           nta_name    boro_ct     state  \
# 14780  QN18                          Rego Park  4068700.0  New York
# 14781  BX03    Eastchester-Edenwald-Baychester  2035800.0  New York
# 14782  MN03  Central Harlem North-Polo Grounds  1023400.0  New York
# 14783  MN31        Lenox Hill-Roosevelt Island  1013400.0  New York
# 14784  MN17               Midtown-Midtown Sout        NaN       NaN
#
#         Latitude  longitude             x_sp            y_sp
# 14780  40.730497 -73.866022   1,021,382.4254  205,444.722034
# 14781  40.873195 -73.842239    1,027,880.458  257,445.488439
# 14782  40.824545 -73.937974  1,001,416.54407  239,687.426843
# 14783  40.771939 -73.957939    995,900.18699  220,517.956652
# 14784        NaN        NaN              NaN             NaN
#
# [5 rows x 42 columns]

# %%
tree_census.columns
# Out:
# Index(['created_at', 'tree_id', 'block_id', 'the_geom', 'tree_dbh',
#        'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common',
#        'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other',
#        'brnch_ligh', 'brnch_shoe', 'brnch_othe', 'address', 'zipcode',
#        'zip_city', 'cb_num', 'borocode', 'boroname', 'cncldist', 'st_assem',
#        'st_senate', 'nta', 'nta_name', 'boro_ct', 'state', 'Latitude',
#        'longitude', 'x_sp', 'y_sp'],
#       dtype='object')

# %%
tree_census.shape
# Out:
# (14785, 42)

# %%
tree_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14785 entries, 0 to 14784
# Data columns (total 42 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  14785 non-null  object
#  1   tree_id     14785 non-null  object
#  2   block_id    14785 non-null  object
#  3   the_geom    14785 non-null  object
#  4   tree_dbh    14785 non-null  int64
#  5   stump_diam  14785 non-null  int64
#  6   curb_loc    14785 non-null  object
#  7   status      14785 non-null  object
#  8   health      13985 non-null  object
#  9   spc_latin   13985 non-null  object
#  10  spc_common  13985 non-null  object
#  11  steward     4803 non-null   object
#  12  guards      2567 non-null   object
#  13  sidewalk    13985 non-null  object
#  14  user_type   14785 non-null  object
#  15  problems    6105 non-null   object
#  16  root_stone  14785 non-null  object
#  17  root_grate  14785 non-null  object
#  18  root_other  14785 non-null  object
#  19  trnk_wire   14785 non-null  object
#  20  trnk_light  14785 non-null  object
#  21  trnk_other  14785 non-null  object
#  22  brnch_ligh  14785 non-null  object
#  23  brnch_shoe  14785 non-null  object
#  24  brnch_othe  14785 non-null  object
#  25  address     14785 non-null  object
#  26  zipcode     14785 non-null  int64
#  27  zip_city    14785 non-null  object
#  28  cb_num      14785 non-null  int64
#  29  borocode    14785 non-null  int64
#  30  boroname    14785 non-null  object
#  31  cncldist    14785 non-null  int64
#  32  st_assem    14785 non-null  int64
#  33  st_senate   14785 non-null  int64
#  34  nta         14785 non-null  object
#  35  nta_name    14785 non-null  object
#  36  boro_ct     14784 non-null  float64
#  37  state       14784 non-null  object
#  38  Latitude    14784 non-null  float64
#  39  longitude   14784 non-null  float64
#  40  x_sp        14784 non-null  object
#  41  y_sp        14784 non-null  object
# dtypes: float64(3), int64(8), object(31)
# memory usage: 4.7+ MB

# %%
tree_census.health.value_counts(dropna=False)
# Out:
# health
# Good    10384
# Fair     2775
# Poor      826
# NaN       800
# Name: count, dtype: int64

# %%
tree_census.status.value_counts(dropna=False)
# Out:
# status
# Alive    13985
# Stump      442
# Dead       358
# Name: count, dtype: int64

# %%
trees_subset = tree_census[['tree_id', 'tree_dbh',
        'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common',
        'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
        'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other',
        'brnch_ligh', 'brnch_shoe', 'brnch_othe']]

trees_subset.head()
# Out:
#    tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0  180,683         3           0   OnCurb  Alive   Fair
# 1  200,540        21           0   OnCurb  Alive   Fair
# 2  204,026         3           0   OnCurb  Alive   Good
# 3  204,337        10           0   OnCurb  Alive   Good
# 4  189,565        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  ...  \
# 0                         Acer rubrum        red maple     NaN    NaN  ...
# 1                   Quercus palustris          pin oak     NaN    NaN  ...
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2    NaN  ...
# 3  Gleditsia triacanthos var. inermis      honeylocust     NaN    NaN  ...
# 4                     Tilia americana  American linden     NaN    NaN  ...
#
#   problems root_stone root_grate root_other trnk_wire trnk_light trnk_other  \
# 0      NaN         No         No         No        No         No         No
# 1   Stones        Yes         No         No        No         No         No
# 2      NaN         No         No         No        No         No         No
# 3   Stones        Yes         No         No        No         No         No
# 4   Stones        Yes         No         No        No         No         No
#
#   brnch_ligh brnch_shoe brnch_othe
# 0         No         No         No
# 1         No         No         No
# 2         No         No         No
# 3         No         No         No
# 4         No         No         No
#
# [5 rows x 22 columns]

# %%
trees_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health          800
# spc_latin       800
# spc_common      800
# steward        9982
# guards        12218
# sidewalk        800
# user_type         0
# problems       8680
# root_stone        0
# root_grate        0
# root_other        0
# trnk_wire         0
# trnk_light        0
# trnk_other        0
# brnch_ligh        0
# brnch_shoe        0
# brnch_othe        0
# dtype: int64

# %%
tree_census.describe()
# Out:
#            tree_dbh    stump_diam      zipcode        cb_num      borocode  \
# count  14785.000000  14785.000000  14785.00000  14785.000000  14785.000000
# mean      10.882448      0.474806  10849.99114    320.910788      3.144944
# std        8.821085      3.535351    749.78560    125.599375      1.265552
# min        0.000000      0.000000     83.00000    101.000000      1.000000
# 25%        4.000000      0.000000  10308.00000    212.000000      2.000000
# 50%        9.000000      0.000000  11206.00000    314.000000      3.000000
# 75%       15.000000      0.000000  11355.00000    407.000000      4.000000
# max      425.000000    140.000000  11697.00000    503.000000      5.000000
#
#            cncldist      st_assem     st_senate       boro_ct      Latitude  \
# count  14785.000000  14785.000000  14785.000000  1.478400e+04  14784.000000
# mean      28.050118     51.717754     21.141427  3.181939e+06     40.706402
# std       15.063825     17.687835      6.970763  1.273470e+06      0.087070
# min        1.000000     23.000000     10.000000  1.000201e+06     40.499417
# 25%       16.000000     36.000000     15.000000  2.042575e+06     40.638187
# 50%       29.000000     52.000000     22.000000  3.059401e+06     40.715941
# 75%       39.000000     65.000000     26.000000  4.071304e+06     40.769529
# max       51.000000     87.000000     36.000000  5.030302e+06     40.906213
#
#           longitude
# count  14784.000000
# mean     -73.945451
# std        0.097496
# min      -74.252169
# 25%      -73.979290
# 50%      -73.948465
# 75%      -73.888871
# max      -73.705470
#            tree_dbh    stump_diam      zipcode        cb_num      borocode  \
# count  14785.000000  14785.000000  14785.00000  14785.000000  14785.000000
# mean      10.882448      0.474806  10849.99114    320.910788      3.144944
# std        8.821085      3.535351    749.78560    125.599375      1.265552
# min        0.000000      0.000000     83.00000    101.000000      1.000000
# 25%        4.000000      0.000000  10308.00000    212.000000      2.000000
# 50%        9.000000      0.000000  11206.00000    314.000000      3.000000
# 75%       15.000000      0.000000  11355.00000    407.000000      4.000000
# max      425.000000    140.000000  11697.00000    503.000000      5.000000
#
#            cncldist      st_assem     st_senate       boro_ct      Latitude  \
# count  14785.000000  14785.000000  14785.000000  1.478400e+04  14784.000000
# mean      28.050118     51.717754     21.141427  3.181939e+06     40.706402
# std       15.063825     17.687835      6.970763  1.273470e+06      0.087070
# min        1.000000     23.000000     10.000000  1.000201e+06     40.499417
# 25%       16.000000     36.000000     15.000000  2.042575e+06     40.638187
# 50%       29.000000     52.000000     22.000000  3.059401e+06     40.715941
# 75%       39.000000     65.000000     26.000000  4.071304e+06     40.769529
# max       51.000000     87.000000     36.000000  5.030302e+06     40.906213
#
#           longitude
# count  14784.000000
# mean     -73.945451
# std        0.097496
# min      -74.252169
# 25%      -73.979290
# 50%      -73.948465
# 75%      -73.888871
# max      -73.705470

# %%
trees_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'tree_dbh'}>,
#         <Axes: title={'center': 'stump_diam'}>]], dtype=object)

# %%
big_trees = trees_subset[trees_subset['tree_dbh']> 50]
big_trees.head()
# Out:
#        tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2385   168,583       425           0          OnCurb  Alive   Good
# 3724   199,546        51           0          OnCurb  Alive   Good
# 4874   139,665        72           0  OffsetFromCurb  Alive   Good
# 6711   209,349       122           0          OnCurb  Alive   Good
# 10053  215,075       169           0          OnCurb  Alive   Good
#
#                                 spc_latin       spc_common steward guards  \
# 2385                      Quercus bicolor  swamp white oak    1or2    NaN
# 3724                     Acer saccharinum     silver maple     NaN    NaN
# 4874                     Acer saccharinum     silver maple     NaN    NaN
# 6711                    Quercus palustris          pin oak     NaN    NaN
# 10053  Gleditsia triacanthos var. inermis      honeylocust     NaN    NaN
#
#        ... problems root_stone root_grate root_other trnk_wire trnk_light  \
# 2385   ...      NaN         No         No         No        No         No
# 3724   ...   Stones        Yes         No         No        No         No
# 4874   ...      NaN         No         No         No        No         No
# 6711   ...      NaN         No         No         No        No         No
# 10053  ...      NaN         No         No         No        No         No
#
#       trnk_other brnch_ligh brnch_shoe brnch_othe
# 2385          No         No         No         No
# 3724          No         No         No         No
# 4874          No         No         No         No
# 6711          No         No         No         No
# 10053         No         No         No         No
#
# [5 rows x 22 columns]

# %%
tree_census.boxplot(column='tree_dbh', by='stump_diam')
# Out:
# <Axes: title={'center': 'tree_dbh'}, xlabel='stump_diam'>

# %%
big_trees[['tree_id', 'tree_dbh']].plot(kind='scatter',x='tree_id', y='tree_dbh')
# Out:
# <Axes: xlabel='tree_id', ylabel='tree_dbh'>
