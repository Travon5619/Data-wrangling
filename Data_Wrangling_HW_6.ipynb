# %% [markdown]
# <a href="https://colab.research.google.com/github/Travon5619/Data-wrangling/blob/main/Data_Wrangling_HW_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_with_outliers = np.array([1, 2, 3, 4, 5, 6, 7, 100, 200, 250, 1000])

threshold = 100

cleaned_data = data_with_outliers[data_with_outliers < threshold]

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
sns.boxplot(y=data_with_outliers)
plt.title('Before Removing Outliers')

plt.subplot(1, 2, 2)
sns.boxplot(y=cleaned_data)
plt.title('After Removing Outliers')

plt.tight_layout()
plt.show()

# %%
print("Original data:", data_with_outliers)
print("Cleaned data:", cleaned_data)
# Out:
# Original data: [   1    2    3    4    5    6    7  100  200  250 1000]
# Cleaned data: [1 2 3 4 5 6 7]
